# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(0,10,0.1)
y=2*np.sin(4*x)-x**2+10*x  #f(x)=2sin(4x)-x^2+10x
plt.plot(x,y)
plt.show()

# %%
import pylab as pl
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

pl.plot(X, C)
pl.plot(X, S)

pl.show()

# %%
data= open(r'C:\Users\Toshiba\Dropbox\LCG\4to semestre\Bioinfo\proyectos\Estrcutural\salida.txt')

# %%
E1=[]
for line in data:
    lin=line.split()
    for e1 in lin:
        print i
        E1.append=(i)
# Out:
# -13.5747487
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-27ef94189d6c> in <module>()
#       4     for i in lin:
#       5         print i
# ----> 6         E1.append=(i)
#
# AttributeError: 'list' object attribute 'append' is read-only

# %%
E1
# Out:
# []

# %%
precio=data.find("b0")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-4fde2012891a> in <module>()
# ----> 1 precio=data.find("b0")
#
# AttributeError: 'file' object has no attribute 'find'

# %%
file=open(r'C:\Users\Toshiba\Dropbox\LCG\4to semestre\Bioinfo\proyectos\Estrcutural\salida.txt','r') 
contenido=file.readlines() 
for i in range contenidos: #(usaré como separador el tabulador) 
    dato1=contenido[i].find('\n') 
    dato2=contenido[i].find('\n',dato1+1) 
    dato3=contenido[i].find('\n',dato2+1)

# %%
import re
file=open(r'C:\Users\Toshiba\Dropbox\LCG\4to semestre\Bioinfo\proyectos\Estrcutural\VALORES DE E1.txt','r') 
data=file.readlines() 
lvalores=[]
dict={}

for lin in data:
    if lin!="VALORES DE E1"+"\n":
        patron= re.compile ('^b\d{4}\n')
        print lin
        if not patron.findall(lin):

            lvalores.append(lin)
# Out:
# b0365
#
# ...

# %%
data1=line[:-1]

# %%
data1
# Out:
# '-15.187888'

# %%
#por contadores o separado
import re
file1=open(r'C:\Users\Toshiba\Dropbox\LCG\4to semestre\Bioinfo\proyectos\Estrcutural\Tarea 2\VALORES DE E1.txt','r')
file2=open(r'C:\Users\Toshiba\Dropbox\LCG\4to semestre\Bioinfo\proyectos\Estrcutural\Tarea 2\VALORES DE E2.txt','r') 
file3=open(r'C:\Users\Toshiba\Dropbox\LCG\4to semestre\Bioinfo\proyectos\Estrcutural\Tarea 2\VALORES DE D.txt','r') 

for i in
data=file1.readlines() 
lsec=data [1::2]
lval=data[2::2]

for lin in data:
    if lin!="VALORES DE E1"+"\n":
        patron= re.compile ('^b\d{4}\n')
        if patron.findall(lin):
            ln.append(lin)
        else:
            lvalores.append(lin)
file.close()

# %%
import re
path= 'C:/Users/Toshiba/Dropbox/LCG/4to semestre/Bioinfo/proyectos/Estrcutural/Tarea 2'
file1=open (path + '/VALORES DE E1.txt', 'r')
file2=open (path + '/VALORES DE E2.txt', 'r')
file3=open (path + '/VALORES DE D.txt', 'r')

data=file1.readlines() 
lsec=data [1::2]
lval=data[2::2]
mydict = {key:value for key, value in zip(lsec,lval)}

# %%
for i in len(mydict):
    [i.split(' ')[i] for i in mydict.values()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-316-469d9022a521> in <module>()
# ----> 1 for i in len(mydict):
#       2     [i.split(' ')[i] for i in mydict.values()]
#
# TypeError: 'int' object is not iterable

# %%
mydict2 = {}
for key, value in zip(lsec,lval):
    key:value
# Out:
#   File "<ipython-input-273-024b3fb90b79>", line 3
#     key:value
#        ^
# SyntaxError: invalid syntax

# %%
data=file1.readlines() 
line = line.strip()

# %%
line
# Out:
# '-15.1878884'

# %%
lsec=data [1::2]
lval=data[2::2]

# %%
mydict = {key:value for key, value in zip(lsec,lval)}

# %%
for i in len(mydict):

# %%
a=float(mydict['b0763\n'].split())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-301-8f8c567b2c6b> in <module>()
# ----> 1 a=float(mydict['b0763\n'].split())
#
# TypeError: float() argument must be a string or a number

# %%
a=mydict.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-302-a3539145e865> in <module>()
# ----> 1 a=mydict.split()
#
# AttributeError: 'dict' object has no attribute 'split'

# %%
type(a)
# Out:
# list

# %%
type(['duck', 'duck', 'goose'])
# Out:
# list

# %%
l=a.split()
import numpy as np
print np.mean(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-282-3ef848a3ba7e> in <module>()
#       1 l=a.split()
#       2 import numpy as np
# ----> 3 print np.mean(l)
#
# C:\Python27\lib\site-packages\numpy\core\fromnumeric.pyc in mean(a, axis, dtype, out, keepdims)
#    2733
#    2734     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2735                             out=out, keepdims=keepdims)
#    2736
#    2737 def std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=False):
#
# C:\Python27\lib\site-packages\numpy\core\_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      64         dtype = mu.dtype('f8')
#      65
# ---> 66     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      67     if isinstance(ret, mu.ndarray):
#      68         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type

# %%
float(l[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-287-4dab5fb1d26d> in <module>()
# ----> 1 float(l)
#
# TypeError: float() argument must be a string or a number

# %%
a=mydict.values()

# %%
c=[float (i.split(' ')[20]) for i in mydict.values()]

# %%
type(c)
# Out:
# list

# %%
list(item.split(" ") for item in s.split("''"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-304-f49f630550f2> in <module>()
# ----> 1 list(item.split(" ") for item in s.split("''"))
#
# NameError: name 's' is not defined

# %%
num    = ['1', '2', '', '6']
type (num)
# Out:
# list

# %%
avgDict = {}
for k,v in mydict.iteritems():
    # v is the list of grades for student k
    avgDict[k] = sum(v)/ float(len(v))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-237-7d3ac5b78a91> in <module>()
#       2 for k,v in mydict.iteritems():
#       3     # v is the list of grades for student k
# ----> 4     avgDict[k] = sum(v)/ float(len(v))
#
# C:\Python27\lib\site-packages\numpy\core\fromnumeric.pyc in sum(a, axis, dtype, out, keepdims)
#    1717         except AttributeError:
#    1718             return _methods._sum(a, axis=axis, dtype=dtype,
# -> 1719                                 out=out, keepdims=keepdims)
#    1720         # NOTE: Dropping the keepdims parameters here...
#    1721         return sum(axis=axis, dtype=dtype, out=out)
#
# C:\Python27\lib\site-packages\numpy\core\_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
# ...

# %%
print lval
# Out:
# ['-13.5747487 -13.6141171 -13.6558089 -13.7024518 -13.7549743 -13.819512 -13.8877715 -13.9489708 -14.0178693 -14.0919258 -14.1610199 -14.2355576 -14.2934937 -14.3361705 -14.3548134 -14.374866 -14.3760427 -14.3538923 -14.3238245 -14.3017306 -14.2706817 -14.2367343 -14.2027869 -14.1688395 -14.1243583 -14.0744335 -14.0363131 -14.0081514 -13.9688543 -13.9246926 -13.8966474 -13.8914933 -13.9071173 -13.925279 -13.9333429 -13.9385722 -13.9353842 -13.9293616 -13.9362714 -13.9598354 -14.004843 -14.0574859 -14.123828 -14.2002679 -14.2868056 -14.3632455 -14.4226478 -14.4719523 -14.5237945 -14.5731742 -14.6328134 -14.7000879 -14.7497045 -14.7615993 -14
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-180-c8a82a0576e8> in <module>()
# ----> 1 sum (array)
#
# C:\Python27\lib\site-packages\numpy\core\fromnumeric.pyc in sum(a, axis, dtype, out, keepdims)
#    1722     else:
#    1723         return _methods._sum(a, axis=axis, dtype=dtype,
# -> 1724                             out=out, keepdims=keepdims)
#    1725
#    1726 def product (a, axis=None, dtype=None, out=None, keepdims=False):
#
# C:\Python27\lib\site-packages\numpy\core\_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# TypeError: cannot perform reduce with flexible type

# %%
array[2]
# Out:
# '-13.6558089'

# %%
np.average(array)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-92bcd200359a> in <module>()
# ----> 1 np.average(array)
#
# C:\Python27\lib\site-packages\numpy\lib\function_base.pyc in average(a, axis, weights, returned)
#     512
#     513     if weights is None:
# --> 514         avg = a.mean(axis)
#     515         scl = avg.dtype.type(a.size/avg.size)
#     516     else:
#
# C:\Python27\lib\site-packages\numpy\core\_methods.pyc in _mean(a, axis, dtype, out, keepdims)
#      64         dtype = mu.dtype('f8')
#      65
# ---> 66     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      67     if isinstance(ret, mu.ndarray):
#      68         ret = um.true_divide(
#
# TypeError: cannot perform reduce with flexible type

# %%
l[1]
# Out:
# '-13.5747487 -13.6141171 -13.6558089 -13.7024518 -13.7549743 -13.819512 -13.8877715 -13.9489708 -14.0178693 -14.0919258 -14.1610199 -14.2355576 -14.2934937 -14.3361705 -14.3548134 -14.374866 -14.3760427 -14.3538923 -14.3238245 -14.3017306 -14.2706817 -14.2367343 -14.2027869 -14.1688395 -14.1243583 -14.0744335 -14.0363131 -14.0081514 -13.9688543 -13.9246926 -13.8966474 -13.8914933 -13.9071173 -13.925279 -13.9333429 -13.9385722 -13.9353842 -13.9293616 -13.9362714 -13.9598354 -14.004843 -14.0574859 -14.123828 -14.2002679 -14.2868056 -14.3632455 -14.4226478 -14.4719523 -14.5237945 -14.5731742 -14.6328134 -14.7000879 -14.7497045 -14.7615993 -14.7521896 -14.7309038 -14.6858849 -14.6247495 -14.5687082 -14.5179675 -14.4732494 -14.4362305 -14.4115689 -14.3922079 -14.3813846 -14.3577793 -14.3473168 -14.344204 -14.3389747 -14.3124144 -14.3153016 -14.3472377 -14.3687791 -14.3858054 -14.419219 -14.4668882 -14.5222831 -14.5651816 -14.5976967 -14.6329599 -14.6570577 -14.6738058 -14.6689938 -14.6885
# ...

# %%
type (contenido[1])
# Out:
# str

# %%
dato2
# Out:
# -1

# %%
dato3
# Out:
# 0

# %%
contenido [1].replace("\n","") == 'b0365\n'
# Out:
# False

# %%
a=contenido [1].replace("\n","")

# %%
a== patron
# Out:
# False

# %%
contenido [1]== patron
# Out:
# False

# %%
patron.findall(contenido)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-075d286d1b30> in <module>()
# ----> 1 patron.findall(contenido)
#
# TypeError: expected string or buffer

# %%
type(contenido)
# Out:
# list

# %%
import re
patron= re.compile ('^b\d{4}\n')

# %%
patron
# Out:
# re.compile(r'^b(\d{4})\n')

# %%
patron.match(cadena)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-a89687ad73f9> in <module>()
# ----> 1 patron.match(cadena)
#
# NameError: name 'cadena' is not defined
